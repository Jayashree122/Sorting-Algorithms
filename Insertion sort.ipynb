# %%
#Insertion sort
def InsertionSort(a):
  for i in range(len(a)):
    b=a[i]
    j=i-1
    while j>=0 and b<a[j]:
      a[j],b=b,a[j]
      j-=1
    a[j+1]=b
  return a

# %%
a=[66,79,65,4895,6365,566]
print(InsertionSort(a))
# Out:
# [66, 79, 65, 4895, 6365, 566]
