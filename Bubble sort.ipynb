# %%
#Bubble sort
def Bubblesort(a):
  for i in range(len(a)):
    for j in range(len(a)-1):
      if a[j]>a[j+1]:
        a[j],a[j+1]=a[j+1],a[j]
  return a

# %%
b=[332,89,674,38]
print(Bubblesort(b))
# Out:
# [38, 89, 332, 674]
