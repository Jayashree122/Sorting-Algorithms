# %%
#Selection sort
def SelectionSort(a):
  for i in range(len(a)):
    min=i
    for j in range(i+1,len(a)):
      if a[min]>a[j]:
        min=j
    a[min],a[i]=a[i],a[min]
  return a

# %%
s=[332,89,674,38]
print(SelectionSort(s))
# Out:
# [38, 89, 332, 674]
